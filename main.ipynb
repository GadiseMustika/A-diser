# %% [markdown]
# Import library python Opencv,Tesseract-ocr, and matplotlib

# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Read Image with open CV

# %%
image = cv2.imread("/home/jupyter/A-diser/OCR/images/tes.png")

# %% [markdown]
# Convert Image to Gray

# %%
color = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# Showing image

# %%
plt.imshow(color)

# %% [markdown]
# Remove some noise

# %%
blur = cv2.GaussianBlur(color,(1,1), 0)
thresh = cv2.threshold(color, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))

# %% [markdown]
# Recognize text with tesseract for python

# %%
result = pytesseract.image_to_string(thresh,lang='ind',config='--psm 4',)
print(result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pytesseract/pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     253     try:
# --> 254         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     255     except OSError as e:
#
# /opt/conda/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ...
